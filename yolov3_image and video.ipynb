# %%
# !ls
# !rm -fr darknet
# !git clone https://github.com/AlexeyAB/darknet/
# Out:
# 3rdparty      cmake		      image_yolov3.sh	     README.md
# appveyor.yml  CMakeLists.txt	      include		     results
# backup	      darknet		      json_mjpeg_streams.sh  scripts
# bad.list      DarknetConfig.cmake.in  LICENSE		     src
# build	      darknet.py	      Makefile		     video_v2.sh
# build.ps1     darknet_video.py	      net_cam_v3.sh	     video_yolov3.sh
# build.sh      data		      obj		     yolov3.weights
# cfg	      image_yolov2.sh	      predictions.jpg
# Cloning into 'darknet'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 11009 (delta 3), reused 5 (delta 2), pack-reused 10996
# Receiving objects: 100% (11009/11009), 10.72 MiB | 21.86 MiB/s, done.
# Resolving deltas: 100% (7396/7396), done.

# %%
# !ls
# %cd darknet
# !ls
% cd ..
# Out:
# 3rdparty      cmake		      image_yolov3.sh	     README.md
# appveyor.yml  CMakeLists.txt	      include		     results
# backup	      darknet		      json_mjpeg_streams.sh  scripts
# bad.list      DarknetConfig.cmake.in  LICENSE		     src
# build	      darknet.py	      Makefile		     video_v2.sh
# build.ps1     darknet_video.py	      net_cam_v3.sh	     video_yolov3.sh
# build.sh      data		      obj		     yolov3.weights
# cfg	      image_yolov2.sh	      predictions.jpg
# /content/darknet/darknet
# 3rdparty      cmake		      image_yolov2.sh	     net_cam_v3.sh
# appveyor.yml  CMakeLists.txt	      image_yolov3.sh	     README.md
# build	      DarknetConfig.cmake.in  include		     scripts
# build.ps1     darknet.py	      json_mjpeg_streams.sh  src
# build.sh      darknet_video.py	      LICENSE		     video_v2.sh
# cfg	      data		      Makefile		     video_yolov3.sh
# /content/darknet

# %%
#Installing CUDA pre-requisites
# !wget https://developer.nvidia.com/compute/cuda/8.0/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# !dpkg -i cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# Out:
# --2019-10-30 15:05:22--  https://developer.nvidia.com/compute/cuda/8.0/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# Resolving developer.nvidia.com (developer.nvidia.com)... 192.229.162.216
# Connecting to developer.nvidia.com (developer.nvidia.com)|192.229.162.216|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://developer.download.nvidia.com/compute/cuda/8.0/secure/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64.deb?eqmGGGKRNeDM8V6Gxmb6S4EbsQL4b_kex_vfKofaB8jRFLcCp42sprMCAPKEC_o3MAx_aZ4k9g_8pSH0mV5sWoKgQAQOT7sWiBavJqrz-XsFPKhvsRc5hv4_FnIJldFjM7mwXuqlmm-Ahf_A5O4lk13JJT-z7L1lO-QWGEO5x_EOVR1hGX1OhGgQfOG4ICuCsZKYZOo2PpE2T26x9tbgOG_KtQ [following]
# ...

# %%
# !apt update
# Out:
# Get:1 file:/var/cuda-repo-8-0-local-ga2  InRelease
# Ign:1 file:/var/cuda-repo-8-0-local-ga2  InRelease
# Get:2 file:/var/cuda-repo-8-0-local-ga2  Release [574 B]
# Get:2 file:/var/cuda-repo-8-0-local-ga2  Release [574 B]
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:4 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:5 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:9 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease
# Hit:10 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:11 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:12 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease
# ...

# %%
#Installing CUDA
# !apt install cuda-8-0 -y

# If there is an issue installing CUDA, 
# try installing cuda-visual-tools again
# Comment the earlier command to install cuda
# Uncomment and run the below command

#!apt --fix-broken install cuda-visual-tools-8-0 -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# cuda-8-0 is already the newest version (8.0.61-1).
# 0 upgraded, 0 newly installed, 0 to remove and 33 not upgraded.

# %%
import os
os.environ['PATH'] += ':/usr/local/cuda/bin'

# %%
#Installing compilers
# !apt install gcc-5 g++-5 -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# g++-5 is already the newest version (5.5.0-12ubuntu1).
# gcc-5 is already the newest version (5.5.0-12ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 33 not upgraded.

# %%
# !ln -s /usr/bin/gcc-5 /usr/local/cuda/bin/gcc 
# !ln -s /usr/bin/g++-5 /usr/local/cuda/bin/g++
# Out:
# ln: failed to create symbolic link '/usr/local/cuda/bin/gcc': File exists
# ln: failed to create symbolic link '/usr/local/cuda/bin/g++': File exists

# %%
import os
os.environ['PATH'] += ':/usr/local/cuda/bin'

# %%
#Changing the variables to include OpenCV and GPU in the Makefile
% cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !sed -i 's/GPU=0/GPU=1/g' Makefile
#!sed -i 's/CUDNN=0/CUDNN=1/g' Makefile
# Out:
# /content/darknet/darknet

# %%
# And this is how our Makefile looks now
# Check if OPENCV = 1 and GPU = 1
# !cat Makefile
# Out:
# GPU=1
# CUDNN=0
# CUDNN_HALF=0
# OPENCV=1
# AVX=0
# OPENMP=0
# LIBSO=0
# ZED_CAMERA=0
#
# # set GPU=1 and CUDNN=1 to speedup on GPU
# # set CUDNN_HALF=1 to further speedup 3 x times (Mixed-precision on Tensor Cores) GPU: Volta, Xavier, Turing and higher
# # set AVX=1 and OPENMP=1 to speedup on CPU (if error occurs then set AVX=0)
#
# DEBUG=0
#
# ARCH= -gencode arch=compute_30,code=sm_30 \
#       -gencode arch=compute_35,code=sm_35 \
#       -gencode arch=compute_50,code=[sm_50,compute_50] \
#       -gencode arch=compute_52,code=[sm_52,compute_52] \
# 	  -gencode arch=compute_61,code=[sm_61,compute_61]
#
# OS := $(shell uname)
#
# # Tesla V100
# # ARCH= -gencode arch=compute_70,code=[sm_70,compute_70]
#
# # GeForce RTX 2080 Ti, RTX 2080, RTX 2070, Quadro RTX 8000, Quadro RTX 6000, Quadro RTX 5000, Tesla T4, XNOR Tensor Cores
# # ARCH= -gencode arch=compute_75,code=[sm_75,compute_75]
#
# # Jetson XAVIER
# # ARCH= -gencode arch=compute_72,code=[sm_72,compute_72]
#
# ...

# %%
# Apparently we need to install this so that OpenCV can work without any issues
# when we are making the file
# !apt-get install libopencv-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libopencv-dev is already the newest version (3.2.0+dfsg-4ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 33 not upgraded.

# %%
#Running make!
# !make
# Out:
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(mat_cv*, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:896:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^
# ./src/image_opencv.cpp: In function ‘image image_data_augmentation(mat_cv*, int, int, int, int, int, int, int, float, float, float, int, int, float*)’:
# ./src/image_opencv.cpp:1205:26: warning: variable ‘kernel_size’ set but not used [-Wunused-but-set-variable]
#                  cv::Size kernel_size = cv::Size(ksize, ksize);
#                           ^
# ...

# %%
# Downloading YOLO weights
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2019-10-30 15:08:55--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  38.8MB/s    in 6.6s
#
# 2019-10-30 15:09:02 (35.9 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# Let's see if it can detect object without any issues.
# Here is an example from YOLO
# !./darknet detect cfg/yolov3.cfg yolov3.weights /content/darknet/data/abc.jpg
# Out:
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   10 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256       3 x 3/ 2    104 x 104 x 128 ->   52 x  52 x 256 1.595 BF
# ...

# %%
# !ls
# Out:
# 3rdparty      CMakeLists.txt	      include		     results
# appveyor.yml  darknet		      json_mjpeg_streams.sh  scripts
# backup	      DarknetConfig.cmake.in  LICENSE		     src
# build	      darknet.py	      Makefile		     video_v2.sh
# build.ps1     darknet_video.py	      net_cam_v3.sh	     video_yolov3.sh
# build.sh      data		      obj		     yolov3.weights
# cfg	      image_yolov2.sh	      predictions.jpg
# cmake	      image_yolov3.sh	      README.md

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#The DOG, The TRUCK and The Bicycle!
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

image = cv2.imread("predictions.jpg")
height, width = image.shape[:2]
resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

fig = plt.gcf()
fig.set_size_inches(18, 10)
plt.axis("off")
#plt.rcParams['figure.figsize'] = [10, 5]
plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# %cd /content/darknet
# !ls
# Out:
# /content/darknet
# 3rdparty					       image_yolov2.sh
# appveyor.yml					       image_yolov3.sh
# backup						       include
# bad.list					       json_mjpeg_streams.sh
# build						       LICENSE
# build.ps1					       Makefile
# build.sh					       net_cam_v3.sh
# cfg						       obj
# cmake						       predictions.jpg
# CMakeLists.txt					       README.md
# cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb  results
# darknet						       scripts
# DarknetConfig.cmake.in				       src
# darknet.py					       video_v2.sh
# darknet_video.py				       video_yolov3.sh
# data						       yolov3.weights

# %%
# Upload the video you want to use for object detection
# Please use a filename without spaces like test.mp4 etc.
# !ls
# %cd data
from google.colab import files
uploaded = files.upload() 
for name, data in uploaded.items():
  with open(name, 'wb') as f:
    f.write(data)
    print ('saved file', name)
# Out:
# 9k.tree     dog.jpg	 horses.jpg		   openimages.names
# abc.jpg     eagle.jpg	 imagenet.labels.list	   person.jpg
# coco9k.map  giraffe.jpg  imagenet.shortnames.list  scream.jpg
# coco.names  goal.txt	 labels			   voc.names
# [Errno 2] No such file or directory: 'data'
# /content/darknet/data
#      <input type="file" id="files-4f7cfe4b-2393-4e00-95c6-78aa93dec527" name="files[]" multiple disabled />
#      <output id="result-4f7cfe4b-2393-4e00-95c6-78aa93dec527">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving world-environment-day-whatsapp-status-2018-5-june-environment-day-whatsapp-status.mp4 to world-environment-day-whatsapp-status-2018-5-june-environment-day-whatsapp-status.mp4
# saved file world-environment-day-whatsapp-status-2018-5-june-environment-day-whatsapp-status.mp4

# %%
# %cd /content/darknet
# Out:
# /content/darknet

# %%
# And finally run it! Please check if you have given the right video file name

# !./darknet detector demo cfg/coco.data cfg/yolov3.cfg yolov3.weights -dont_show /content/darknet/data/world-environment-day-whatsapp-status-2018-5-june-environment-day-whatsapp-status.mp4 -i 0 -out_filename resv.avi
# !ls
# Out:
# /bin/bash: ./darknet: Is a directory
# 3rdparty					       image_yolov2.sh
# appveyor.yml					       image_yolov3.sh
# backup						       include
# bad.list					       json_mjpeg_streams.sh
# build						       LICENSE
# build.ps1					       Makefile
# build.sh					       net_cam_v3.sh
# cfg						       obj
# cmake						       predictions.jpg
# CMakeLists.txt					       README.md
# cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb  results
# darknet						       scripts
# DarknetConfig.cmake.in				       src
# darknet.py					       video_v2.sh
# darknet_video.py				       video_yolov3.sh
# data						       yolov3.weights

# %%
# Upload the video you want to use for object detection
# Please use a filename without spaces like test.mp4 etc.
# %cd 
# %cd /content/darknet/data
# !ls
from google.colab import files
uploaded = files.upload() 
for name, data in uploaded.items():
  with open(name, 'wb') as f:
    f.write(data)
    print ('saved file', name)
# Out:
# /root
# /content/darknet/data
# 9k.tree
# abc.jpg
# coco9k.map
# coco.names
# dog.jpg
# eagle.jpg
# giraffe.jpg
# goal.txt
# horses.jpg
# imagenet.labels.list
# imagenet.shortnames.list
# labels
# openimages.names
# person.jpg
# scream.jpg
# voc.names
# world-environment-day-whatsapp-status-2018-5-june-environment-day-whatsapp-status.mp4
#      <input type="file" id="files-b15e9e56-b408-4cbf-8eb5-6814c8f0661d" name="files[]" multiple disabled />
#      <output id="result-b15e9e56-b408-4cbf-8eb5-6814c8f0661d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving world-environment-day-whatsapp-status-2018-5-june-environment-day-whatsapp-status.mp4 to world-environment-day-whatsapp-status-2018-5-june-environment-day-whatsapp-status (1).mp4
# ...

# %%
# !ls
# Out:
#  9k.tree
#  abc.jpg
#  coco9k.map
#  coco.names
#  dog.jpg
#  eagle.jpg
#  giraffe.jpg
#  goal.txt
#  horses.jpg
#  imagenet.labels.list
#  imagenet.shortnames.list
#  labels
#  openimages.names
#  person.jpg
#  scream.jpg
#  voc.names
# 'world-environment-day-whatsapp-status-2018-5-june-environment-day-whatsapp-status (1).mp4'
#  world-environment-day-whatsapp-status-2018-5-june-environment-day-whatsapp-status.mp4

# %%
# And finally run it! Please check if you have given the right video file name
# %cd
# %cd/content/darknet

# !./darknet detector demo cfg/coco.data cfg/yolov3.cfg yolov3.weights -dont_show /content/darknet/darknet/data/world-environment-day-whatsapp-status-2018-5-june-environment-day-whatsapp-status.mp4 -i 0 -out_filename res2.avi
# !ls
# Out:
# /root
# /content/darknet
# /bin/bash: ./darknet: Is a directory
# 3rdparty					       image_yolov2.sh
# appveyor.yml					       image_yolov3.sh
# backup						       include
# bad.list					       json_mjpeg_streams.sh
# build						       LICENSE
# build.ps1					       Makefile
# build.sh					       net_cam_v3.sh
# cfg						       obj
# cmake						       predictions.jpg
# CMakeLists.txt					       README.md
# cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb  results
# darknet						       scripts
# DarknetConfig.cmake.in				       src
# darknet.py					       video_v2.sh
# darknet_video.py				       video_yolov3.sh
# data						       yolov3.weights

# %%
files.download('/content/darknet/res2.avi')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-65-bd7d7f5ac651> in <module>()
#       1
# ----> 2 files.download('/content/darknet/res2.avi')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     142       raise OSError(msg)
#     143     else:
# --> 144       raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     145
#     146   started = _threading.Event()
#
# FileNotFoundError: Cannot find file: /content/darknet/res2.avi

# %%
# %cd
# %cd /content/darknet
# Out:
# /root
# /content/darknet

# %%
# !./darknet detect cfg/yolov3.cfg yolov3.weights data/IMG-20190820-WA0026.jpg
# Out:
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   10 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256       3 x 3/ 2    104 x 104 x 128 ->   52 x  52 x 256 1.595 BF
# ...

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

image = cv2.imread("predictions.jpg")
height, width = image.shape[:2]
resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

fig = plt.gcf()
fig.set_size_inches(18, 10)
plt.axis("off")
#plt.rcParams['figure.figsize'] = [10, 5]
plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# !./darknet detector demo cfg/coco.data cfg/yolov3.cfg yolov3.weights -dont_show data/InShot_20190820_194108493.mp4 -i 0 -out_filename res3.avi
# Out:
# Demo
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   10 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256       3 x 3/ 2    104 x 104 x 128 ->   52 x  52 x 256 1.595 BF
# ...
